# %% [markdown]
# <a href="https://colab.research.google.com/github/marcelo0211/arquivos/blob/master/Case_Final_Estatistica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import random
from scipy.stats import norm 
import scipy.stats as st
import seaborn as sns

# %%
filmes = pd.read_csv('/content/n_movies.csv')
filmes
# Out:
#                        title         year certificate duration  \
# 0                  Cobra Kai     (2018– )       TV-14   30 min
# 1                  The Crown     (2016– )       TV-MA   58 min
# 2           Better Call Saul  (2015–2022)       TV-MA   46 min
# 3              Devil in Ohio       (2022)       TV-MA  356 min
# 4     Cyberpunk: Edgerunners     (2022– )       TV-MA   24 min
# ...                      ...          ...         ...      ...
# 9952          The Imperfects     (2022– )       TV-MA   45 min
# 9953        The Walking Dead  (2010–2022)       TV-MA   44 min
# 9954               The Crown     (2016– )       TV-MA   58 min
# 9955            Supernatural  (2005–2020)       TV-14   44 min
# 9956           Devil in Ohio       (2022)       TV-MA  356 min
#
#                              genre  rating  \
# 0            Action, Comedy, Drama     8.5
# 1        Biography, Drama, History     8.7
# 2                     Crime, Drama     8.9
# ...

# %%
#Tirar as principais medidas das variaveis rating 
# Perceber que a media esta bem proxima da mediana. 
filmes.describe()
# Out:
#             rating
# count  8784.000000
# mean      6.764515
# std       1.214840
# min       1.700000
# 25%       6.100000
# 50%       6.900000
# 75%       7.600000
# max       9.900000

# %%
#Plotar o histograma e boxplot
sns.histplot(data=filmes, x='rating',kde= True )
# Out:
# <Axes: xlabel='rating', ylabel='Count'>

# %%
#Boxplot
sns.boxplot(data=filmes, x='rating')
# Out:
# <Axes: xlabel='rating'>

# %%
#AMOSTRAGEM SIMPLES E ALEATORIA 
#Determine a quantidade ideal de elementos para esta amostra dato o tamanho do dataset
#Considere o escore_z como 1.96, desvio padrao como 0.5, margem de erro em 0.05 e estraia a quantidade da população
#Utilize a seguinte formula pra calcular

# %%
#Calcule o tamanho da amostra 
filmes.shape
# Out:
# (9957, 9)

# %%
filmes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9957 entries, 0 to 9956
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        9957 non-null   object
#  1   year         9430 non-null   object
#  2   certificate  6504 non-null   object
#  3   duration     7921 non-null   object
#  4   genre        9884 non-null   object
#  5   rating       8784 non-null   float64
#  6   description  9957 non-null   object
#  7   stars        9957 non-null   object
#  8   votes        8784 non-null   object
# dtypes: float64(1), object(8)
# memory usage: 700.2+ KB

# %%
filmes.isnull().sum()
# Out:
# title             0
# year            527
# certificate    3453
# duration       2036
# genre            73
# rating         1173
# description       0
# stars             0
# votes          1173
# dtype: int64

# %%
filmes =filmes.dropna()
filmes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5754 entries, 0 to 9956
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        5754 non-null   object
#  1   year         5754 non-null   object
#  2   certificate  5754 non-null   object
#  3   duration     5754 non-null   object
#  4   genre        5754 non-null   object
#  5   rating       5754 non-null   float64
#  6   description  5754 non-null   object
#  7   stars        5754 non-null   object
#  8   votes        5754 non-null   object
# dtypes: float64(1), object(8)
# memory usage: 449.5+ KB

# %%
filmes.isnull().sum()
# Out:
# title          0
# year           0
# certificate    0
# duration       0
# genre          0
# rating         0
# description    0
# stars          0
# votes          0
# dtype: int64

# %%
#calcular o tamanho da amostra 
#Considere o escore_z como 1.96, desvio padrao como 0.5, margem de erro em 0.05 e estraia a quantidade da população
z = 1.96
p = 0.5
e = 0.05
n = 5754    #POPULACAO
tamanho_amostra = ((z**2)*p*(1-p)/(e**2))/1+(((z**2)*p*(1-p))/((e**2)*n))
tamanho_amostra
# Out:
# 384.22676399026756

# %%
#Amostra simples

amostra_simples = filmes.sample(385, replace= True )
amostra_simples
# Out:
#                              title         year certificate duration  \
# 1354                  The Get Down  (2016–2017)       TV-MA   52 min
# 298                        Godless       (2017)       TV-MA  452 min
# 1426             Isn't It Romantic       (2019)       PG-13   89 min
# 8222                        Bleach  (2004–2012)       TV-14   24 min
# 2132                         Ghoul       (2018)       TV-MA   45 min
# ...                            ...          ...         ...      ...
# 2336  Put Your Head on My Shoulder       (2019)       TV-14   45 min
# 2255                 From the Dark       (2014)     Unrated   90 min
# 25                            NCIS     (2003– )       TV-14   60 min
# 3672                     Bongwater       (1998)           R   97 min
# 2487        Meenakshi Sundareshwar       (2021)       TV-14  140 min
#
#                              genre  rating  \
# 1354         Drama, Music, Musical     8.2
# 298         Action, Drama, Western     8.3
# ...

# %%
#Amostra sistematica para saltar de 5 em 5
def amostragem_sistematica(df,step):
  indexes = np.arange(5, len(df), step=step)
  amostragem_sistematica = df.iloc[indexes]
  return amostragem_sistematica
amostra_sistematica = amostragem_sistematica(filmes, 5)  

#Visualizar a minha funcao 
amostra_sistematica.head()
# Out:
#               title         year certificate duration                   genre  \
# 5       The Sandman     (2022– )       TV-MA   45 min  Drama, Fantasy, Horror
# 10  Stranger Things     (2016– )       TV-14   51 min  Drama, Fantasy, Horror
# 15        I Came By       (2022)       TV-MA  110 min                Thriller
# 22     Supernatural  (2005–2020)       TV-14   44 min  Drama, Fantasy, Horror
# 27        Shameless  (2011–2021)       TV-MA   46 min           Comedy, Drama
#
#     rating                                        description  \
# 5      7.8  Upon escaping after decades of imprisonment by...
# 10     8.7  When a young boy disappears, his mother, a pol...
# 15     6.1  Follows a young graffiti artist who discovers ...
# 22     8.4  Two brothers follow their father's footsteps a...
# 27     8.6  A scrappy, feisty, fiercely loyal Chicago fami...
#
#                                                 stars      votes
# ...

# %%
#Verificar a distribuicao por histrograma da minha variavel "Rating"
sns.histplot(data=filmes, x='rating', kde = True )
# Out:
# <Axes: xlabel='rating', ylabel='Count'>

# %%
#Transformar a coluna rating em l
rating_values = filmes.rating.values.tolist()
print(rating_values)
# Out:
# [8.5, 8.7, 8.9, 5.9, 8.6, 7.8, 9.2, 9.5, 6.3, 6.2, 8.7, 4.7, 8.1, 8.1, 6.4, 6.1, 5.8, 8.8, 8.8, 7.6, 8.4, 8.0, 7.4, 7.8, 8.9, 8.6, 8.5, 8.5, 5.9, 6.5, 5.0, 8.5, 8.5, 8.2, 8.0, 8.9, 8.1, 7.9, 8.5, 6.8, 5.3, 8.8, 8.4, 8.0, 8.2, 8.4, 8.0, 7.9, 9.0, 7.1, 7.3, 6.1, 8.7, 8.4, 9.0, 7.7, 7.4, 8.2, 8.9, 8.2, 6.3, 8.3, 7.6, 8.5, 8.6, 7.7, 8.2, 6.5, 8.5, 7.4, 8.0, 9.0, 8.8, 8.3, 7.6, 7.8, 7.5, 6.6, 8.6, 8.7, 7.6, 8.6, 8.5, 8.6, 8.1, 7.7, 6.3, 3.3, 6.6, 7.9, 7.3, 9.1, 8.7, 7.7, 8.5, 6.7, 7.8, 8.1, 8.7, 8.9, 7.5, 8.7, 8.8, 8.4, 8.2, 8.1, 8.2, 8.3, 8.4, 7.7, 7.6, 7.6, 8.1, 5.8, 8.7, 8.5, 6.9, 7.5, 8.7, 8.6, 7.4, 8.6, 7.1, 7.6, 5.4, 7.7, 7.7, 7.7, 8.7, 8.4, 7.6, 6.8, 7.3, 8.8, 7.9, 8.3, 8.6, 8.4, 7.4, 8.4, 2.7, 7.2, 8.2, 8.4, 7.6, 5.4, 8.5, 8.5, 7.7, 6.2, 8.2, 7.7, 7.2, 8.0, 8.5, 7.5, 7.8, 8.2, 7.5, 6.6, 7.3, 2.6, 7.9, 8.7, 6.3, 8.5, 8.4, 8.1, 7.4, 5.0, 8.5, 8.4, 8.7, 8.4, 7.1, 7.2, 6.8, 7.5, 8.4, 7.8, 7.5, 8.1, 8.1, 8.8, 4.7, 9.3, 8.5, 7.8, 6.7, 5.7, 7.7, 7.5, 8.1, 7.0, 8.3, 6.2, 8.3, 8.4, 7.6, 8.
# ...

# %%
#Extraia a quantiadade de amostras aleatorias com base na quantidade de amostras tiradas pelo calculo
pop = rating_values
means = []
for i in range(385):
  sample = random.sample(pop,k=385)
  means.append(np.mean(sample))
means
# Out:
# [6.942597402597402,
#  6.872467532467533,
#  6.846753246753247,
#  6.826233766233766,
#  6.839480519480519,
#  6.775064935064935,
#  6.771428571428571,
#  6.759740259740259,
#  6.856883116883116,
#  6.752987012987013,
#  6.847792207792208,
#  6.728571428571429,
#  6.776623376623377,
#  6.839220779220778,
#  6.777662337662337,
#  6.835324675324675,
#  6.855324675324676,
#  6.746493506493507,
#  6.752987012987013,
#  6.764155844155844,
#  6.76077922077922,
#  6.758181818181819,
#  6.702597402597402,
#  6.825194805194805,
#  6.818441558441558,
#  6.763636363636364,
#  6.782077922077923,
#  6.76987012987013,
#  6.7677922077922075,
#  6.852467532467532,
#  6.826493506493506,
#  6.779220779220779,
#  6.702597402597402,
#  6.808051948051948,
#  6.704935064935065,
#  6.685714285714286,
#  6.847012987012985,
#  6.8644155844155845,
#  6.675844155844155,
#  6.75168831168831,
#  6.756103896103897,
#  6.684935064935066,
#  6.896883116883116,
#  6.905714285714285,
#  6.796363636363636,
# ...

# %%
#Média das amostras 
np.mean(means)
# Out:
# 6.78970214201383

# %%
#Média Populacional
np.mean(pop)
# Out:
# 6.792822384428223

# %%
#Histograma da medias amostrais

sns.histplot(means, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
# INTERVALO DE SEGURANCA
test_95 = st.norm.interval(alpha=0.95, loc=np.mean(means), scale = st.sem(means))
test_95
# Out:
# <ipython-input-22-28afa890dbeb>:2: DeprecationWarning: Use of keyword argument 'alpha' for method 'interval' is deprecated and wil be removed in SciPy 1.11.0. Use first positional argument or keyword argument 'confidence' instead.
#   test_95 = st.norm.interval(alpha=0.95, loc=np.mean(means), scale = st.sem(means))
# (6.783496166894994, 6.795908117132666)

# %%
# faça uma amostra probabilistica simples sem repetiçoes com o tamanho da amostra estimada no exercicio anterior
