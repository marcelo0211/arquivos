# %% [markdown]
# <a href="https://colab.research.google.com/github/marcelo0211/arquivos/blob/master/Melhoria_projeto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy as np
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)
from datetime import datetime

# %%
df = pd.read_csv('/content/30_dias___conteudos_com_temas_relacionados_2023-05-05T12_31_04.890034Z.csv')
df1 = pd.read_csv('/content/30_dias___tabela_fato_interacoes_2023-05-05T12_30_37.210655Z.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 10 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   id                                              214 non-null    int64
#  1   content_topic - content_topic_id → id           214 non-null    int64
#  2   content_topic - content_topic_id → description  214 non-null    object
#  3   content_topic - content_topic_id → key          214 non-null    object
#  4   forum_content - forum_post_id → id              214 non-null    int64
#  5   forum_content - forum_post_id → title           214 non-null    object
#  6   forum_content - forum_post_id → created_at      214 non-null    object
#  7   forum_content - forum_post_id → is_anonymous    214 non-null    bool
#  8   forum_content - forum_post_id → type            214 non-null    object
# ...

# %%
df.head()
# Out:
#      id  content_topic - content_topic_id → id  \
# 0  2286                                    118
# 1  2287                                    114
# 2  2288                                    120
# 3  2289                                     54
# 4  2290                                     57
#
#   content_topic - content_topic_id → description  \
# 0                                Coronariopatias
# 1                             Cardiointensivismo
# 2                                  Dislipidemias
# 3                           Hipertensão Arterial
# 4                             Eletrocardiografia
#
#   content_topic - content_topic_id → key  forum_content - forum_post_id → id  \
# 0             cardiogram_coronariopatias                                6457
# 1          cardiogram_cardiointensivismo                                6457
# 2               cardiogram_dislipidemias                                6466
# ...

# %% [markdown]
# **Separando data e hora da coluna "orum_content - forum_post_id → created_at"**

# %%
df['data'] = df['forum_content - forum_post_id → created_at'].str.slice(0,10)

# %%
df
# Out:
#        id  content_topic - content_topic_id → id  \
# 0    2286                                    118
# 1    2287                                    114
# 2    2288                                    120
# 3    2289                                     54
# 4    2290                                     57
# 5    2292                                    114
# 6    2293                                    159
# 7    2295                                    176
# 8    2296                                    124
# 9    2298                                    112
# 10   2299                                    118
# 11   2300                                    120
# 12   2302                                    177
# 13   2303                                    176
# 14   2305                                    112
# 15   2306                                    118
# 16   2307                                    120
# 17   2312                                    114
# ...

# %% [markdown]
# **ELiminando colunas **

# %%
#Eliminando a coluna "forum_content - forum_post_id → created_at" substituida pela coluna Data
df= df.drop('forum_content - forum_post_id → created_at', axis='columns')

# %%
#Eliminando a coluna "content_topic - content_topic_id → key" tem igualdade com a coluna "content_topic - content_topic_id → description"
df = df.drop('content_topic - content_topic_id → key', axis='columns')

# %%
#Eliminando a coluna "forum_content - forum_post_id → is_anonymous" 
df = df.drop('forum_content - forum_post_id → is_anonymous', axis='columns')

# %%
df.head()
# Out:
#      id  content_topic - content_topic_id → id  \
# 0  2286                                    118
# 1  2287                                    114
# 2  2288                                    120
# 3  2289                                     54
# 4  2290                                     57
#
#   content_topic - content_topic_id → description  \
# 0                                Coronariopatias
# 1                             Cardiointensivismo
# 2                                  Dislipidemias
# 3                           Hipertensão Arterial
# 4                             Eletrocardiografia
#
#    forum_content - forum_post_id → id  \
# 0                                6457
# 1                                6457
# 2                                6466
# 3                                6466
# 4                                6466
#
#                forum_content - forum_post_id → title  \
# 0  Atualização em anticoagulação na Síndrome Coro...
# ...
