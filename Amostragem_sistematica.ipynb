# %% [markdown]
# <a href="https://colab.research.google.com/github/marcelo0211/arquivos/blob/master/Amostragem_sistematica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy as np

# %%
#importar o csv
iris_df = pd.read_csv('/content/Iris.csv')
iris_df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
# quantidade de linhas e colunas 
iris_df.shape
# Out:
# (150, 6)

# %%
#Amostra aleatoria simples
amostra_simples = iris_df.sample(30,replace=True)

# %%
amostra_simples.head()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 1      2            4.9           3.0            1.4           0.2
# 56    57            6.3           3.3            4.7           1.6
# 133  134            6.3           2.8            5.1           1.5
# 104  105            6.5           3.0            5.8           2.2
# 12    13            4.8           3.0            1.4           0.1
#
#              Species
# 1        Iris-setosa
# 56   Iris-versicolor
# 133   Iris-virginica
# 104   Iris-virginica
# 12       Iris-setosa

# %%
amostra_simples.shape
# Out:
# (30, 6)

# %%
#AMOSTRAGEM SISTEMATICA
iris_df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris_df.shape
# Out:
# (150, 6)

# %%
#Criar uma funcao para pegar uma amostra sistemática

def amostragem_sistematica(df, step):
  indexes = np.arange(3, len(df), step=step)
  amostra_sistematica = iris_df.iloc[indexes]
  return(amostra_sistematica)

amostra_sistemataca= amostragem_sistematica(iris_df,3)

display(amostra_sistemataca )
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 3      4            4.6           3.1            1.5           0.2
# 6      7            4.6           3.4            1.4           0.3
# 9     10            4.9           3.1            1.5           0.1
# 12    13            4.8           3.0            1.4           0.1
# 15    16            5.7           4.4            1.5           0.4
# 18    19            5.7           3.8            1.7           0.3
# 21    22            5.1           3.7            1.5           0.4
# 24    25            4.8           3.4            1.9           0.2
# 27    28            5.2           3.5            1.5           0.2
# 30    31            4.8           3.1            1.6           0.2
# 33    34            5.5           4.2            1.4           0.2
# 36    37            5.5           3.5            1.3           0.2
# 39    40            5.1           3.4            1.5           0.2
# ...
